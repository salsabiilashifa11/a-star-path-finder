# %%
import pandas as pd
import gmaps
import gmaps.datasets
# from haversine import haversine, Unit
from math import radians, cos, sin, asin, sqrt


gmaps.configure(api_key='AIzaSyBlvE6HXrmuztPHa5sa6JIKXraPGrGlBcc')

# gmaps.configure(api_key='AIzaSyD5stgJJJrNxYzs-LmovhImoNiVIdrGc8Y')

frontgate = (-6.893216, 107.610438)
simpangDago = (-6.885203, 107.613683)
tigaanBorromeus = (-6.893766, 107.612949)
tamansari = (-6.887369, 107.611171)
jlnA = (-6.892063, 107.610400)
depanGKUB = (-6.890145, 107.609066)
jlnII = (-6.891070, 107.608713)
jlnIV = (-6.889914, 107.610417)
belakang = (-6.887850, 107.610500)


fig = gmaps.figure()
frontgateBorom = gmaps.directions_layer(jlnIV, belakang,show_markers = False, travel_mode='WALKING')
belakangSimpang = gmaps.directions_layer(belakang, simpangDago,show_markers = False, travel_mode='WALKING')
fig.add_layer(frontgateBorom)
fig.add_layer(belakangSimpang)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
class Node:
    def __init__(self, nPred, location, next, trail):
        self.nPred = nPred #int
        self.location = location #location
        self.next = next #Node
        self.trail = trail #SuccNode

class SuccNode:
    def __init__(self, succ, nextT, weight):
        self.succ = succ #Node
        self.nextT = nextT #SuccNode
        self.weight = weight #float

class Graph:
    def __init__(self, First):
        self.First = First #Node

    def SearchNode(self, loc):
        P = self.First
        while (P != None and (P.location.name != loc.name)):
            P = P.next 
        return P

    def SearchEdge(self, prec, succ): #SuccNode
        P = self.SearchNode(prec)
        if (P == None):
            return None
        T = P.trail 
        if (T == None):
            return None
        while (T.succ.location.name != succ and T.nextT != None):
            T = T.nextT
        if (T.succ.location.name != succ):
            return None 
        return T                    
            
    def InsertNode(self, location):
        Last = self.First
        
        P = Node(0, location, None, None)
        if (P != None):
            while (Last.next != None) :
                Last = Last.next
            Last.next = P
    
    def InsertEdge(self, source, destination, weight):
        Pprec = self.SearchNode(source)
        Psucc = self.SearchNode(destination)

        if (self.SearchEdge(source, destination) == None):
            T = Pprec.trail

            if (T == None):
                temp = SuccNode(Psucc, None, weight)
                Pprec.trail = temp
            else:
                while (T.nextT != None):
                    T = T.nextT 
                temp = SuccNode(Psucc, None, weight)
                T.nextT = temp
            Psucc.nPred += 1
        
        Pprec = self.SearchNode(destination)
        Psucc = self.SearchNode(source)

        if (self.SearchEdge(destination, source) == None):
            T = Pprec.trail

            if (T == None):
                temp = SuccNode(Psucc, None, weight)
                Pprec.trail = temp
            else:
                while (T.nextT != None):
                    T = T.nextT
                temp = SuccNode(Psucc, None, weight)
                T.nextT = temp
            Psucc.nPred += 1
            
class Location:
    def __init__(self, longitude, latitude, name):
        self.longitude = longitude
        self.latitude = latitude
        self.name = name

# %%
def cariWeight(loc1, loc2):
    return (loc1.longitude + loc2.longitude + loc1.latitude + loc2.latitude)

Kubus = Location(3.0, 5.0, "Kubus")
simpangan1 = Location(4.0, 5.0, "Simpangan 1")
simpangan2 = Location(0.0, 0.0, "Simpangan 2")
simpangan3 = Location(0.0, 0.0, "Simpangan 3")

A = Node(0, Kubus, None, None)

graph = Graph(A)
graph.InsertNode(simpangan1)
graph.InsertNode(simpangan2)
graph.InsertNode(simpangan3)

weight1 = cariWeight(Kubus, simpangan1)
weight2 = cariWeight(Kubus, simpangan2)
weight3 = cariWeight(simpangan2, simpangan3)
weight4 = cariWeight(Kubus, simpangan3)

graph.InsertEdge(Kubus, simpangan1, weight1)
graph.InsertEdge(Kubus, simpangan2, weight2)
graph.InsertEdge(simpangan2, simpangan3, weight3)
graph.InsertEdge(Kubus, simpangan3, weight4)

#DEBUG
print(graph.First.location.name)

print(graph.SearchNode(Kubus).location.name)
print(graph.SearchNode(simpangan1).location.name)
print(graph.First.nPred)

TrailA = A.trail
while (TrailA != None):
    print(TrailA.weight)
    TrailA = TrailA.nextT
# Out:
# Kubus
# Kubus
# Simpangan 1
# 3
# 17.0
# 8.0
# 8.0

# %%
def distance(loc1, loc2):
    return sqrt((loc1.longitude - loc2.longitude)**2 + (loc1.latitude - loc2.latitude)**2)

def h(loc1, loc2):
    # The math module contains a function named
    # radians which converts from degrees to radians.
    lon1 = radians(loc1.latitude)
    lon2 = radians(loc2.latitude)
    lat1 = radians(loc1.longitude)
    lat2 = radians(loc2.longitude)

    # Haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1
    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2

    c = 2 * asin(sqrt(a)) 

    # Radius of earth in kilometers. Use 3956 for miles
    r = 6371

    # calculate the result
    return(c * r)

# %%
def AStar(graph, start, end):
    opened = [start]
    closed = []
    g = {}
    parents = {}
    
    g[start] = 0
    
    parents[start] = start
    
    while (len(opened) > 0):
        n = None
        
        for alive in opened:
            if (n == None or g[alive] + h(alive.location, end.location) < g[n] + h(n.location, end.location)):
                n = alive
                
        if (n == end or graph.SearchNode(n.location) == None):
            pass
        else:
            p = n.trail
            while (p != None):
                if (p.succ not in opened and p.succ not in closed):
                    opened.append(p.succ)
                    parents[p.succ] = n
                    g[p.succ] = g[n] + p.weight
                else:
                    if (g[p.succ] > g[n] + p.weight):
                        g[p.succ] = g[n] + p.weight
                        parents[p.succ] = n
                        
                        if (p.succ in closed):
                            closed.remove(p.succ)
                            opened.append(p.succ)
                p = p.nextT
        
        if (n == None):
            print("Gaada jalan")
            return
        
        if (n == end):
            path = []
            
            while (parents[n] != n):
                path.append(n)
                n = parents[n]
                
            path.append(start)
            path.reverse()
            
            #DEBUG RESULT
            print("Path found: ")
            for node in path:
                print(node.location.name)
            return path
            return
        
        
        opened.remove(n)
        closed.append(n)
    
    print("Gaada jalan")
    return

# %%
A = Location(-2, 4, "A")
B = Location(-5, -4, "B")
C = Location(0, 0, "C")
D = Location(4, 3, "D")
E = Location(4, 3, "E")

NodeA = Node(0, A, None, None)

graph = Graph(NodeA)
graph.InsertNode(B)
graph.InsertNode(C)
graph.InsertNode(D)
graph.InsertNode(E)

graph.InsertEdge(A, C, distance(A,C))
graph.InsertEdge(A, D, distance(A,D))
graph.InsertEdge(B, C, distance(B,C))
graph.InsertEdge(B, D, distance(B,D))
graph.InsertEdge(C, D, distance(C,D))

# %%
NodeB = graph.SearchNode(B)
NodeC = graph.SearchNode(C)
NodeD = graph.SearchNode(D)
NodeE = graph.SearchNode(E)
AStar(graph, NodeA, NodeB)
# Out:
# Path found:
# A
# C
# B
# ...

# %%
# #DEBUG
# #A* testing with map 

# Loc1 = Location(-6.89264, 107.61041, "1")
# Loc2 = Location(-6.89265, 107.60875, "2")
# Loc3 = Location(-6.89190, 107.61038, "3")
# Loc4 = Location(-6.89189, 107.60974, "4")
# Loc5 = Location(-6.89186, 107.61100, "5")
# Loc6 = Location(-6.89136, 107.61104, "6")
# Loc7 = Location(-6.89103, 107.61104, "7")
# Loc8 = Location(-6.89103, 107.60971, "8")
# Loc9 = Location(-6.89201, 107.60873, "9")
# Loc10 = Location(-6.89104, 107.6087, "10")
# Loc11 = Location(-6.89234, 107.60827, "11")

# #Graph  initialization
# Node1 = Node(0, Loc1, None, None)
# graph = Graph(Node1)

# #Node insertion
# graph.InsertNode(Loc2)
# graph.InsertNode(Loc3)
# graph.InsertNode(Loc4)
# graph.InsertNode(Loc5)
# graph.InsertNode(Loc6)
# graph.InsertNode(Loc7)
# graph.InsertNode(Loc8)
# graph.InsertNode(Loc9)
# graph.InsertNode(Loc10)
# graph.InsertNode(Loc11)

# #Edge insertion
# graph.InsertEdge(Loc1, Loc2, h(Loc1,Loc2))
# graph.InsertEdge(Loc1, Loc3, h(Loc1,Loc3))
# graph.InsertEdge(Loc2, Loc9, h(Loc2,Loc9))
# graph.InsertEdge(Loc2, Loc11, h(Loc2,Loc11))
# graph.InsertEdge(Loc3, Loc4, h(Loc3,Loc4))
# graph.InsertEdge(Loc3, Loc5, h(Loc3,Loc5))
# graph.InsertEdge(Loc4, Loc8, h(Loc4,Loc8))
# graph.InsertEdge(Loc5, Loc6, h(Loc5,Loc6))
# graph.InsertEdge(Loc6, Loc7, h(Loc6,Loc7))
# graph.InsertEdge(Loc7, Loc8, h(Loc7,Loc8))
# graph.InsertEdge(Loc8, Loc10, h(Loc8,Loc10))
# graph.InsertEdge(Loc9, Loc10, h(Loc9,Loc10))

# %%
#TESTING
Start = graph.SearchNode(Loc4)
End = graph.SearchNode(Loc11)

path = AStar(graph, Start, End)

fig2 = gmaps.figure()
if (path != None):
    for i in range(len(path)-1):
        a = (path[i].location.longitude, path[i].location.latitude)
        b = (path[i+1].location.longitude, path[i+1].location.latitude)

        fig2.add_layer(gmaps.directions_layer(a, b, show_markers = False, travel_mode='WALKING'))
fig2
# Out:
# Path found:
# 4
# 3
# 1
# 2
# 11
# Figure(layout=FigureLayout(height='420px'))

# %%
result = 0
result += h(Loc4, Loc8)
result += h(Loc8, Loc10)
result += h(Loc10, Loc9)
result += h(Loc9, Loc2)
result += h(Loc2, Loc11)
print(result)
#Note: salah, kayanya salah di rumus heuristiknya
# Out:
# 0.4495082977371587

# %%
result = 0
result += h(Loc4, Loc3)
result += h(Loc3, Loc1)
result += h(Loc1, Loc2)
result += h(Loc2, Loc11)
print(result)
# Out:
# 0.3994763743636484

# %%
#GRAPH SETUP - ITB
#Location
Loc1 = Location(-6.89264, 107.61041, "1")
Loc2 = Location(-6.89265, 107.60875, "2")
Loc3 = Location(-6.891934, 107.610384, "3")
Loc4 = Location(-6.89189, 107.60974, "4")
Loc5 = Location(-6.89186, 107.61100, "5")
Loc6 = Location(-6.891350, 107.611042, "6")
Loc7 = Location(-6.89103, 107.61104, "7")
Loc8 = Location(-6.89103, 107.60971, "8")
Loc9 = Location(-6.89201, 107.60873, "9")
Loc10 = Location(-6.89104, 107.6087, "10")
Loc11 = Location(-6.89234, 107.60827, "11")
Loc12 = Location(-6.89104, 107.60822, "12")
Loc13 = Location(-6.89068, 107.60871, "13")
Loc14 = Location(-6.890133, 107.609033, "14")
Loc15 = Location(-6.89013, 107.60819, "15")
Loc16 = Location(-6.88796, 107.60837, "16")
Loc17 = Location(-6.88876, 107.60904, "17")
Loc18 = Location(-6.88994, 107.60907, "18")
Loc19 = Location(-6.88799, 107.60925, "19")
Loc20 = Location(-6.88784, 107.61028, "20")
Loc21 = Location(-6.888484, 107.609289, "21")
Loc22 = Location(-6.8887, 107.61036, "22")
Loc23 = Location(-6.888319, 107.610390, "23")
Loc24 = Location(-6.889260, 107.610462, "24")
Loc25 = Location(-6.889248, 107.610285, "25")
Loc26 = Location(-6.890441, 107.610370, "26")
Loc48 = Location(-6.891330, 107.612178, "48")
Loc49 = Location(-6.89197, 107.61217, "49")
Loc50 = Location(-6.89242, 107.61187, "50")
Loc51 = Location(-6.89097, 107.6121, "51")
Loc52 = Location(-6.89083, 107.61235, "52")
Loc53 = Location(-6.88954, 107.6125, "53")
Loc54 = Location(-6.89099, 107.61157, "54")
Loc55 = Location(-6.89084, 107.61152, "55")
Loc56 = Location(-6.89084, 107.6107, "56")
Loc57 = Location(-6.89102, 107.61068, "57")
Loc58 = Location(-6.89103, 107.61038, "58")
Loc59 = Location(-6.8899, 107.61038, "59")
Loc60 = Location(-6.88989, 107.61152, "60")
Loc61 = Location(-6.88944, 107.61158, "61")
Loc62 = Location(-6.889129, 107.611576, "62")
Loc63 = Location(-6.88921, 107.61253, "63")
Loc64 = Location(-6.88832, 107.61273, "64")
Loc65 = Location(-6.88874, 107.61157, "65")
Loc66 = Location(-6.88818, 107.61152, "66")
Loc67 = Location(-6.88784, 107.61147, "67")
Loc68 = Location(-6.89063, 107.60908, "68")
Loc70 = Location(-6.89051, 107.61201, "70")
Loc71 = Location(-6.89049, 107.61157, "71")
Loc72 = Location(-6.89215, 107.61195, "72")
Loc73 = Location(-6.89198, 107.61167, "73")
Loc74 = Location(-6.89135, 107.61163, "74")

#Graph  initialization
Node1 = Node(0, Loc1, None, None)
graph = Graph(Node1)

#Node Insertion
graph.InsertNode(Loc2)
graph.InsertNode(Loc3)
graph.InsertNode(Loc4)
graph.InsertNode(Loc5)
graph.InsertNode(Loc6)
graph.InsertNode(Loc7)
graph.InsertNode(Loc8)
graph.InsertNode(Loc9)
graph.InsertNode(Loc10)
graph.InsertNode(Loc11)
graph.InsertNode(Loc12)
graph.InsertNode(Loc13)
graph.InsertNode(Loc14)
graph.InsertNode(Loc15)
graph.InsertNode(Loc16)
graph.InsertNode(Loc17)
graph.InsertNode(Loc18)
graph.InsertNode(Loc19)
graph.InsertNode(Loc20)
graph.InsertNode(Loc21)
graph.InsertNode(Loc22)
graph.InsertNode(Loc23)
graph.InsertNode(Loc24)
graph.InsertNode(Loc25)
graph.InsertNode(Loc26)
graph.InsertNode(Loc48)
graph.InsertNode(Loc49)
graph.InsertNode(Loc50)
graph.InsertNode(Loc51)
graph.InsertNode(Loc52)
graph.InsertNode(Loc53)
graph.InsertNode(Loc54)
graph.InsertNode(Loc55)
graph.InsertNode(Loc56)
graph.InsertNode(Loc57)
graph.InsertNode(Loc58)
graph.InsertNode(Loc59)
graph.InsertNode(Loc60)
graph.InsertNode(Loc61)
graph.InsertNode(Loc62)
graph.InsertNode(Loc63)
graph.InsertNode(Loc64)
graph.InsertNode(Loc65)
graph.InsertNode(Loc66)
graph.InsertNode(Loc67)
graph.InsertNode(Loc68)
graph.InsertNode(Loc70)
graph.InsertNode(Loc71)
graph.InsertNode(Loc72)
graph.InsertNode(Loc73)
graph.InsertNode(Loc74)

#Edge Insertion
graph.InsertEdge(Loc1, Loc2, h(Loc1,Loc2))
graph.InsertEdge(Loc1, Loc3, h(Loc1,Loc3))
graph.InsertEdge(Loc2, Loc9, h(Loc2,Loc9))
graph.InsertEdge(Loc2, Loc11, h(Loc2,Loc11))
graph.InsertEdge(Loc3, Loc4, h(Loc3,Loc4))
graph.InsertEdge(Loc3, Loc5, h(Loc3,Loc5))
graph.InsertEdge(Loc4, Loc8, h(Loc4,Loc8))
graph.InsertEdge(Loc5, Loc6, h(Loc5,Loc6))
graph.InsertEdge(Loc6, Loc7, h(Loc6,Loc7))
graph.InsertEdge(Loc8, Loc10, h(Loc8,Loc10))
graph.InsertEdge(Loc9, Loc10, h(Loc9,Loc10))
graph.InsertEdge(Loc1, Loc50, h(Loc1,Loc50))
graph.InsertEdge(Loc3, Loc58, h(Loc3,Loc58))
graph.InsertEdge(Loc6, Loc74, h(Loc6,Loc74))
graph.InsertEdge(Loc7, Loc57, h(Loc7,Loc57))
graph.InsertEdge(Loc7, Loc54, h(Loc7,Loc54))
graph.InsertEdge(Loc8, Loc58, h(Loc8,Loc58))
graph.InsertEdge(Loc10, Loc12, h(Loc10,Loc12))
graph.InsertEdge(Loc10, Loc13, h(Loc10,Loc13))
graph.InsertEdge(Loc11, Loc12, h(Loc11,Loc12))
graph.InsertEdge(Loc11, Loc15, h(Loc11,Loc15))
graph.InsertEdge(Loc13, Loc68, h(Loc13,Loc68))
graph.InsertEdge(Loc14, Loc15, h(Loc14,Loc15))
graph.InsertEdge(Loc14, Loc18, h(Loc14,Loc18))
graph.InsertEdge(Loc14, Loc68, h(Loc14,Loc68))
graph.InsertEdge(Loc15, Loc16, h(Loc15,Loc16))
graph.InsertEdge(Loc16, Loc19, h(Loc16,Loc19))
graph.InsertEdge(Loc17, Loc18, h(Loc17,Loc18))
graph.InsertEdge(Loc17, Loc21, h(Loc17,Loc21))
graph.InsertEdge(Loc17, Loc22, h(Loc17,Loc22))
graph.InsertEdge(Loc18, Loc59, h(Loc18,Loc59))
graph.InsertEdge(Loc19, Loc21, h(Loc19,Loc21))
graph.InsertEdge(Loc19, Loc20, h(Loc19,Loc20))
graph.InsertEdge(Loc20, Loc23, h(Loc20,Loc23))
graph.InsertEdge(Loc20, Loc67, h(Loc20,Loc67))
graph.InsertEdge(Loc21, Loc22, h(Loc21,Loc22))
graph.InsertEdge(Loc22, Loc23, h(Loc22,Loc23))
graph.InsertEdge(Loc22, Loc25, h(Loc22,Loc25))
graph.InsertEdge(Loc22, Loc65, h(Loc22,Loc65))
graph.InsertEdge(Loc22, Loc24, h(Loc22,Loc24))
graph.InsertEdge(Loc24, Loc25, h(Loc24,Loc25))
graph.InsertEdge(Loc24, Loc59, h(Loc24,Loc59))
graph.InsertEdge(Loc25, Loc59, h(Loc25,Loc59))
graph.InsertEdge(Loc26, Loc58, h(Loc26,Loc58))
graph.InsertEdge(Loc26, Loc59, h(Loc26,Loc59))
graph.InsertEdge(Loc48, Loc49, h(Loc48,Loc49))
graph.InsertEdge(Loc48, Loc51, h(Loc48,Loc51))
graph.InsertEdge(Loc48, Loc74, h(Loc48,Loc74))
graph.InsertEdge(Loc49, Loc72, h(Loc49,Loc72))
graph.InsertEdge(Loc50, Loc72, h(Loc50,Loc72))
graph.InsertEdge(Loc51, Loc54, h(Loc51,Loc54))
graph.InsertEdge(Loc51, Loc52, h(Loc51,Loc52))
graph.InsertEdge(Loc51, Loc70, h(Loc51,Loc70))
graph.InsertEdge(Loc52, Loc53, h(Loc52,Loc53))
graph.InsertEdge(Loc53, Loc61, h(Loc53,Loc61))
graph.InsertEdge(Loc53, Loc63, h(Loc53,Loc63))
graph.InsertEdge(Loc54, Loc55, h(Loc54,Loc55))
graph.InsertEdge(Loc55, Loc71, h(Loc55,Loc71))
graph.InsertEdge(Loc55, Loc56, h(Loc55,Loc56))
graph.InsertEdge(Loc56, Loc57, h(Loc56,Loc57))
graph.InsertEdge(Loc57, Loc58, h(Loc57,Loc58))
graph.InsertEdge(Loc59, Loc60, h(Loc59,Loc60))
graph.InsertEdge(Loc60, Loc61, h(Loc60,Loc61))
graph.InsertEdge(Loc60, Loc71, h(Loc60,Loc71))
graph.InsertEdge(Loc61, Loc62, h(Loc61,Loc62))
graph.InsertEdge(Loc62, Loc63, h(Loc62,Loc63))
graph.InsertEdge(Loc62, Loc65, h(Loc62,Loc65))
graph.InsertEdge(Loc63, Loc64, h(Loc63,Loc64))
graph.InsertEdge(Loc64, Loc66, h(Loc64,Loc66))
graph.InsertEdge(Loc65, Loc66, h(Loc65,Loc66))
graph.InsertEdge(Loc66, Loc67, h(Loc66,Loc67))
graph.InsertEdge(Loc70, Loc71, h(Loc70,Loc71))
graph.InsertEdge(Loc72, Loc73, h(Loc72,Loc73))
graph.InsertEdge(Loc73, Loc74, h(Loc73,Loc74))

# %%
#GRAPH SETUP - BUAH BATU
#Location
Loc1 = Location(-6.936757, 107.622691, "1")
Loc2 = Location(-6.947901, 107.633486, "2")
Loc3 = Location(-6.947165, 107.636042, "3")
Loc4 = Location(-6.941532, 107.634648, "4")
Loc5 = Location(-6.93784, 107.6272, "5")
Loc6 = Location(-6.94008, 107.62576, "6")
Loc7 = Location(-6.94199, 107.62754, "7")
Loc8 = Location(-6.94937, 107.62593, "8")
Loc9 = Location(-6.9396, 107.63096, "9")
Loc10 = Location(-6.93691, 107.63211, "10")

#Graph  initialization
Node1 = Node(0, Loc1, None, None)
graph = Graph(Node1)

#Node Insertion
graph.InsertNode(Loc2)
graph.InsertNode(Loc3)
graph.InsertNode(Loc4)
graph.InsertNode(Loc5)
graph.InsertNode(Loc6)
graph.InsertNode(Loc7)
graph.InsertNode(Loc8)
graph.InsertNode(Loc9)
graph.InsertNode(Loc10)

#Edge Insertion
graph.InsertEdge(Loc1, Loc6, h(Loc1,Loc6))
graph.InsertEdge(Loc2, Loc3, h(Loc2,Loc3))
graph.InsertEdge(Loc2, Loc7, h(Loc2,Loc7))
graph.InsertEdge(Loc2, Loc8, h(Loc2,Loc8))
graph.InsertEdge(Loc3, Loc4, h(Loc3,Loc4))
graph.InsertEdge(Loc4, Loc9, h(Loc4,Loc9))
graph.InsertEdge(Loc5, Loc6, h(Loc5,Loc6))
graph.InsertEdge(Loc5, Loc9, h(Loc5,Loc9))
graph.InsertEdge(Loc6, Loc7, h(Loc6,Loc7))
graph.InsertEdge(Loc7, Loc8, h(Loc7,Loc8))
graph.InsertEdge(Loc9, Loc10, h(Loc9,Loc10))

# %%
#GRAPH SETUP - ALUN-ALUN
#Location
Loc1 = Location(-6.922019, 107.604031, "1")
Loc2 = Location(-6.920773, 107.604115, "2")
Loc3 = Location(-6.922231, 107.605329, "3")
Loc4 = Location(-6.920906, 107.605070, "4")
Loc5 = Location(-6.923253, 107.605288, "5")
Loc6 = Location(-6.923342, 107.606328, "6")
Loc7 = Location(-6.922362, 107.606395, "7")
Loc8 = Location(-6.922507, 107.607622, "8")
Loc9 = Location(-6.9212, 107.60771, "9")
Loc10 = Location(-6.92105, 107.60645, "10")
Loc11 = Location(-6.92122, 107.60805, "11")
Loc12 = Location(-6.92017, 107.6082, "12")
Loc13 = Location(-6.91998, 107.60659, "13")
Loc14 = Location(-6.91928, 107.60421, "14")
Loc15 = Location(-6.9183, 107.60427, "15")
Loc16 = Location(-6.91867, 107.60543, "16")
Loc17 = Location(-6.91934, 107.60523, "17")
Loc18 = Location(-6.91906, 107.60663, "18")

#Graph  initialization
Node1 = Node(0, Loc1, None, None)
graph = Graph(Node1)

#Node Insertion
graph.InsertNode(Loc2)
graph.InsertNode(Loc3)
graph.InsertNode(Loc4)
graph.InsertNode(Loc5)
graph.InsertNode(Loc6)
graph.InsertNode(Loc7)
graph.InsertNode(Loc8)
graph.InsertNode(Loc9)
graph.InsertNode(Loc10)
graph.InsertNode(Loc11)
graph.InsertNode(Loc12)
graph.InsertNode(Loc13)
graph.InsertNode(Loc14)
graph.InsertNode(Loc15)
graph.InsertNode(Loc16)
graph.InsertNode(Loc17)
graph.InsertNode(Loc18)

#Edge Insertion
graph.InsertEdge(Loc1, Loc2, h(Loc1,Loc2))
graph.InsertEdge(Loc1, Loc3, h(Loc1,Loc3))
graph.InsertEdge(Loc2, Loc4, h(Loc2,Loc4))
graph.InsertEdge(Loc2, Loc14, h(Loc2,Loc14))
graph.InsertEdge(Loc3, Loc7, h(Loc3,Loc7))
graph.InsertEdge(Loc4, Loc10, h(Loc4,Loc10))
graph.InsertEdge(Loc4, Loc17, h(Loc4,Loc17))
graph.InsertEdge(Loc5, Loc6, h(Loc5,Loc6))
graph.InsertEdge(Loc6, Loc7, h(Loc6,Loc7))
graph.InsertEdge(Loc7, Loc8, h(Loc7,Loc8))
graph.InsertEdge(Loc8, Loc9, h(Loc8,Loc9))
graph.InsertEdge(Loc9, Loc10, h(Loc9,Loc10))
graph.InsertEdge(Loc9, Loc11, h(Loc9,Loc11))
graph.InsertEdge(Loc10, Loc13, h(Loc10,Loc13))
graph.InsertEdge(Loc11, Loc12, h(Loc11,Loc12))
graph.InsertEdge(Loc12, Loc13, h(Loc12,Loc13))
graph.InsertEdge(Loc13, Loc18, h(Loc13,Loc18))
graph.InsertEdge(Loc14, Loc15, h(Loc14,Loc15))
graph.InsertEdge(Loc14, Loc17, h(Loc14,Loc17))
graph.InsertEdge(Loc15, Loc16, h(Loc15,Loc16))
graph.InsertEdge(Loc16, Loc17, h(Loc16,Loc17))
graph.InsertEdge(Loc16, Loc18, h(Loc16,Loc18))

# %%
#GRAPH SETUP - CILANDAK
#Location
Loc1 = Location(-6.28237, 106.79168, "1")
Loc2 = Location(-6.277134, 106.797717, "2")
Loc3 = Location(-6.27765, 106.79972, "3")
Loc4 = Location(-6.279222, 106.799541, "4")
Loc5 = Location(-6.27771, 106.80103, "5")
Loc6 = Location(-6.27778, 106.80234, "6")
Loc7 = Location(-6.27845, 106.80104, "7")
Loc8 = Location(-6.27854, 106.8024, "8")
Loc9 = Location(-6.27935, 106.80245, "9")
Loc10 = Location(-6.279333, 106.797155, "10")
Loc11 = Location(-6.28, 106.79501, "11")
Loc12 = Location(-6.282486, 106.799448, "12")
Loc13 = Location(-6.28475, 106.78813, "13")
Loc14 = Location(-6.283768, 106.796058, "14")
Loc15 = Location(-6.282235, 106.796173, "15")

#Graph  initialization
Node1 = Node(0, Loc1, None, None)
graph = Graph(Node1)

#Node Insertion
graph.InsertNode(Loc2)
graph.InsertNode(Loc3)
graph.InsertNode(Loc4)
graph.InsertNode(Loc5)
graph.InsertNode(Loc6)
graph.InsertNode(Loc7)
graph.InsertNode(Loc8)
graph.InsertNode(Loc9)
graph.InsertNode(Loc10)
graph.InsertNode(Loc11)
graph.InsertNode(Loc12)
graph.InsertNode(Loc13)
graph.InsertNode(Loc14)
graph.InsertNode(Loc15)

#Edge Insertion
graph.InsertEdge(Loc1, Loc11, h(Loc1,Loc11))
graph.InsertEdge(Loc1, Loc13, h(Loc1,Loc13))
graph.InsertEdge(Loc1, Loc14, h(Loc1,Loc14))
graph.InsertEdge(Loc2, Loc3, h(Loc2,Loc3))
graph.InsertEdge(Loc2, Loc10, h(Loc2,Loc10))
graph.InsertEdge(Loc3, Loc4, h(Loc3,Loc4))
graph.InsertEdge(Loc3, Loc5, h(Loc3,Loc5))
graph.InsertEdge(Loc4, Loc9, h(Loc4,Loc9))
graph.InsertEdge(Loc4, Loc10, h(Loc4,Loc10))
graph.InsertEdge(Loc4, Loc12, h(Loc4,Loc12))
graph.InsertEdge(Loc5, Loc6, h(Loc5,Loc6))
graph.InsertEdge(Loc5, Loc7, h(Loc5,Loc7))
graph.InsertEdge(Loc6, Loc8, h(Loc6,Loc8))
graph.InsertEdge(Loc7, Loc8, h(Loc7,Loc8))
graph.InsertEdge(Loc8, Loc9, h(Loc8,Loc9))
graph.InsertEdge(Loc10, Loc11, h(Loc10,Loc11))
graph.InsertEdge(Loc10, Loc15, h(Loc10,Loc15))
graph.InsertEdge(Loc12, Loc15, h(Loc12,Loc15))
graph.InsertEdge(Loc14, Loc15, h(Loc14,Loc15))

# %%
#TESTING
Start = graph.SearchNode(Loc11)
End = graph.SearchNode(Loc10)

path = AStar(graph, Start, End)

fig2 = gmaps.figure()
if (path != None):
    for i in range(len(path)-1):
        a = (path[i].location.longitude, path[i].location.latitude)
        b = (path[i+1].location.longitude, path[i+1].location.latitude)
        temp = gmaps.directions_layer(a, b, show_markers=False, travel_mode='WALKING')
        fig2.add_layer(temp)
fig2
# Out:
# Path found:
# 11
# 10
# 15
# Figure(layout=FigureLayout(height='420px'))
